# %% [markdown]
# ## Config

# %%
dataset_name = 'EmoEvent (Raw)'
labels_column = 'labels'    # emotion

limit_columns = True
limit_column_names = ['text']

remove_others = True

sample_size = 50
random_seed = 418   #   I'm a teacup

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
from config_files import dataset_config

dataset_metadata = dataset_config.dataset[dataset_name]

file_location = f"./{dataset_metadata['relpath']}"

if dataset_metadata['filetype'] == 'csv':
    df_full_dataset = pd.read_csv(file_location)
elif dataset_metadata['filetype'] == 'tsv':
    df_full_dataset = pd.read_csv(file_location, sep="\t")

df_full_dataset
# Out:
#                                   id          event  \
# 0     3B9XR6P1WE1U78OX08FW8NXJL93BJG      NotreDame
# 1     3P4ZBJFX2V96Q90CC9K7G3IC235WFF      Venezuela
# 2     3IQ9O0AYW65Y8JY8ICLHWGO5E1JIT6         LaLiga
# 3     3XEIP58NL0TWKWFD977CAKHEG1ZLZ3         LaLiga
# 4     3BFNCI9LYKWWKIJIK6BTNEUY6MU37E  GretaThunberg
# ...                              ...            ...
# 7261  3TTPFEFXCTQSAQCCGHV3LUVCUGPH6X      Venezuela
# 7262  3XT3KXP24Z4S6LNWMZDOL6WRUT46IF      NotreDame
# 7263  3EHIMLB7F75FE4V09WS158R30BIH8M  GameOfThrones
# 7264  3MYASTQBG7H48SQU9UQB0EX52P7DQG      NotreDame
# 7265  3CO05SML7VBAL940AXRGQXNR4M1R03      Venezuela
#
#                                                   tweet offensive  emotion
# 0     I know that the Notre Dame is a very important...        NO   others
# 1     #BREAKING:  (USER) -- Trump threatens `full an...        NO   others
# 2     #Barcelona will win La Liga with three games t...        NO   others
# 3     HT: Decent half. A goal would've been good tho...        NO   others
# 4     In the 20th century we had weeping statues of ...        NO   others
# ...                                                 ...       ...      ...
# 7261  With regime change yet to take hold in #Venezu...        NO     fear
# 7262  #NotreDameCathedralFire Fantastic the response...        NO   others
# 7263  For those of you questioning the Arya thing. P...        NO   others
# 7264  Respect for people in france who've lost a his...        NO  sadness
# 7265  Socialism always ends up in brutal and forcefu...       OFF      joy
#
# [7266 rows x 5 columns]

# %%
df_full_dataset.drop(columns = dataset_metadata['unused_columns'], inplace=True)
df_full_dataset.rename(columns = dataset_metadata['remap_columns'], inplace=True)

display(df_full_dataset)

full_label_count =  pd.Series(df_full_dataset.labels).value_counts()
print(full_label_count)
# Out:
#               event                                               text  \
# 0         NotreDame  I know that the Notre Dame is a very important...
# 1         Venezuela  #BREAKING:  (USER) -- Trump threatens `full an...
# 2            LaLiga  #Barcelona will win La Liga with three games t...
# 3            LaLiga  HT: Decent half. A goal would've been good tho...
# 4     GretaThunberg  In the 20th century we had weeping statues of ...
# ...             ...                                                ...
# 7261      Venezuela  With regime change yet to take hold in #Venezu...
# 7262      NotreDame  #NotreDameCathedralFire Fantastic the response...
# 7263  GameOfThrones  For those of you questioning the Arya thing. P...
# 7264      NotreDame  Respect for people in france who've lost a his...
# 7265      Venezuela  Socialism always ends up in brutal and forcefu...
#
#        labels
# 0      others
# 1      others
# 2      others
# 3      others
# 4      others
# ...       ...
# 7261     fear
# 7262   others
# 7263   others
# 7264  sadness
# 7265      joy
#
# [7266 rows x 3 columns]
# labels
# others      3283
# joy         2034
# disgust      760
# sadness      414
# anger        390
# surprise     234
# fear         151
# Name: count, dtype: int64

# %%
if remove_others:
    df_full_dataset = df_full_dataset[df_full_dataset['labels'] != 'others']
    display(df_full_dataset)

    full_label_count =  pd.Series(df_full_dataset.labels).value_counts()
full_label_percentages = full_label_count / full_label_count.sum() * 100
print(full_label_percentages)
# Out:
#                 event                                               text  \
# 8           Venezuela  USER People of #Venezuela !! so hilarious movi...
# 10    ChampionsLeague  Remarkable match &amp; Incredible performance ...
# 11      GameOfThrones  That episode of Game Of Thrones was not as gre...
# 12      GameOfThrones  #AvengersEndGame may have had the visual and w...
# 14    ChampionsLeague  Lmao. Liverpool are done 😂. 🐐 Makes it 2-0  #U...
# ...               ...                                                ...
# 7255     WorldBookDay  #WorldBookDay in words of #IvoAndric #NobelPri...
# 7258    GretaThunberg  Dear Politicians: Next election, you will want...
# 7261        Venezuela  With regime change yet to take hold in #Venezu...
# 7264        NotreDame  Respect for people in france who've lost a his...
# 7265        Venezuela  Socialism always ends up in brutal and forcefu...
#
#        labels
# 8     disgust
# 10        joy
# 11      anger
# 12        joy
# 14        joy
# ...       ...
# 7255      joy
# 7258    anger
# 7261     fear
# 7264  sadness
# 7265      joy
#
# [3983 rows x 3 columns]
# labels
# joy         51.067035
# disgust     19.081095
# sadness     10.394175
# anger        9.791614
# surprise     5.874969
# fear         3.791112
# Name: count, dtype: float64

# %%
df_subset = df_full_dataset.groupby('labels', group_keys=False).apply(
    lambda x: x.sample(frac=0.0125, random_state = random_seed)     # Get a random, stratified sample
)
df_subset = df_subset.sample(frac=1, random_state=random_seed)  # Shuffle rows
df_subset
# Out:
# C:\Users\Dave\AppData\Local\Temp\ipykernel_2236\315190765.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_subset = df_full_dataset.groupby('labels', group_keys=False).apply(
#                 event                                               text  \
# 3948  ChampionsLeague  Sometimes you just have to admire the genius o...
# 5636     WorldBookDay  If anyone wants to give me a book as a gift, I...
# 507      WorldBookDay  On #WorldBookDay I am curled up with a book my...
# 5454    GretaThunberg  Very wise words USER_arrowsmith ...we should a...
# 2819  ChampionsLeague  FH underway... Hope's to USER #Liverpool to wi...
# 5252     WorldBookDay  Happy world book day from Globeprep! What are ...
# 444     GameOfThrones  Damn....Game of Thrones sounds crazy! Can’t fo...
# 3329     WorldBookDay  As we celebrate world book day, make sure to i...
# 4879  ChampionsLeague  More #ChampionsLeague action kicking off at 8p...
# 4625    GameOfThrones  That was the best bit of tv I have ever watche...
# 5315    GretaThunberg  Greta Thunberg:  The hero we need, or the resu...
# 4039        Venezuela  #JorgeArreaza President #Trump, so they have t...
# 2958  ChampionsLeague  USER been pretty impressive up to now, Mane ha...
# 6108    GameOfThrones  I'm just so angry because my absolute favourit...
# 1019  ChampionsLeague  Nobody can make you feel inferior without your...
# 5019        Venezuela  FREEDOM for the People of Venezuela 🇻🇪  We are...
# 7264        NotreDame  Respect for people in france who've lost a his...
# 1950     WorldBookDay  There are many little ways to enlarge your chi...
# 7040        NotreDame  Billionaires pledging tons of money to fix a c...
# 5709    GameOfThrones  Wow. Just watched latest episode. Amazing! Tim...
# 558     GretaThunberg  New translation project! So excited! #scenerur...
# 6441        Venezuela  I’ve had CNN in the background most of the day...
# 2859        NotreDame  I am sad about what happened to Notre-Dame bec...
# 5772        NotreDame  The Left: Burn! Burn you symbol of Christian c...
# 6510    GameOfThrones  ARYA OH MY GOD YOU FUCKING BAD ASS BITCH I LOV...
# 3869        Venezuela  USER USER USER well, there were plenty of "evi...
# 3511  ChampionsLeague  Didn’t deserve to lose that 3-0, but one team ...
# 2814  ChampionsLeague  600 goals for my main man Messi in all competi...
# 7120     WorldBookDay  Happy World Book Day #WorldBookDay 🎶Nwanne Wa ...
# 2279           LaLiga                    oh shit now we have 26  #LaLiga
# 990   ChampionsLeague  Wish my teams were playing in the finals than ...
# 7083           LaLiga  Million Dollar Smile..  GOAT got his 10th Leag...
# 31       WorldBookDay  On #WorldBookDay, be inspired by these amazing...
# 4854     WorldBookDay  Beloved books 📚. The gateway to history, disco...
# 974      WorldBookDay  Happy #CanadaBookDay! Only 2 more days to go u...
# 3152    GameOfThrones  The real question we’re now all asking is how ...
# 6959        NotreDame  My Gosh 💔💔 Pain in one part of the body ... wh...
# 45      GameOfThrones  I actually cried at the end, you all thought a...
# 6559    GameOfThrones  1. we waited 8 seasons before we can finally s...
# 1824        Venezuela  What is happening now in #Venezuela is unaccep...
# 5744        NotreDame  i cry for my brothers in Paris and for those a...
# 2577    GameOfThrones  Arya is awesome... That's all I have to say......
# 971   ChampionsLeague  Only the 5th best player in the world has gone...
# 4724     WorldBookDay  #WorldBookDay: Ten memorable scenes from Hindi...
# 4291        Venezuela  Wow! Shits bout to get real folks!  https://t....
# 1313    GretaThunberg  #GretaThunberg should absolutely be nominated ...
# 5193    GameOfThrones  #Endgame and #GameofThrones both in the one ni...
# 5930  ChampionsLeague  Great ball by Alba, wonderful run &amp; finish...
# 2285        Venezuela  What is happening right now in #Venezuela, in ...
# 2638        Venezuela  USER What more of a civil war than the rampant...
#
#         labels
# 3948       joy
# 5636       joy
# 507        joy
# 5454       joy
# 2819       joy
# 5252       joy
# 444    disgust
# 3329       joy
# 4879       joy
# 4625       joy
# 5315   disgust
# 4039     anger
# 2958       joy
# 6108     anger
# 1019       joy
# 5019     anger
# 7264   sadness
# 1950       joy
# 7040   disgust
# 5709       joy
# 558        joy
# 6441   disgust
# 2859   sadness
# 5772     anger
# 6510       joy
# 3869   disgust
# 3511       joy
# 2814       joy
# 7120       joy
# 2279  surprise
# 990    sadness
# 7083       joy
# 31         joy
# 4854       joy
# 974        joy
# 3152     anger
# 6959  surprise
# 45         joy
# 6559   sadness
# 1824   disgust
# 5744   sadness
# 2577       joy
# 971    disgust
# 4724   disgust
# 4291   disgust
# 1313      fear
# 5193  surprise
# 5930       joy
# 2285      fear
# 2638   disgust

# %%
subset_label_count = pd.Series(df_subset.labels).value_counts()
print(subset_label_count)
subset_label_percentages = subset_label_count / subset_label_count.sum() * 100
print(subset_label_percentages)
# Out:
# labels
# joy         25
# disgust     10
# anger        5
# sadness      5
# surprise     3
# fear         2
# Name: count, dtype: int64
# labels
# joy         50.0
# disgust     20.0
# anger       10.0
# sadness     10.0
# surprise     6.0
# fear         4.0
# Name: count, dtype: float64

# %% [markdown]
# ## Export

# %%
df_subset['text'].to_csv(f"./subset/EmoEvents_raw_subset_unlabeled.csv", index=True)
df_subset.to_csv(f"./subset/EmoEvents_raw_subset_original_labels.csv", index=True)
