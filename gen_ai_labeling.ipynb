# %% [markdown]
# # Config

# %%
import_location = 'datasets/emoevent/raw/full_subset/emoevent_crowdsourced_400.csv'
export_location = 'datasets/emoevent/raw/full_subset/ai_labeled/'
export_name = 'emoevent_ai_labeled_wo_others.csv'

datasets = ['EmoEvent']
ai_models = ['Llama3.1 8B instruct-q8', 'DeepSeek-R1 14B', 'GPT 4o-mini', 'o3-mini'] # 'Llama3.1 8B instruct-q8', 'DeepSeek-R1 14B', 'GPT 4o-mini', 'o3-mini'
overwrite_previous_labels = False
deterministic = False

random_seed = 418   #   I'm a teacup

from config_files.dataset_config import dataset as dataset_config
from config_files import gen_ai_config

# %%
import pandas as pd
import os
import ollama
from ollama import ResponseError
from openai import OpenAI

# %% [markdown]
# # Label Generation Functions

# %% [markdown]
# ### Build Label Prompt

# %%
def build_label_prompt(dataset_id, text, event = None):
    from config_files import prompts

    prompt = prompts.prompt[dataset_id]['labels'].replace('<text>', text)
    prompt = prompt.replace('<context>', prompts.prompt[dataset_id]['context'][event])

    return prompt

# %% [markdown]
# ### Generate AI Label

# %%
def generate_synthetic_label(genAI_details, label_prompt, num_labelers = 1):
    if genAI_details["platform"] == "Ollama":
        response = ollama.chat(
            model=genAI_details["id"],
            messages=[{
                "role": "user",
                "content": label_prompt
            }],
            options={"top_k":1, "temperature":0.0}   # Greedy
        )
        return response["message"]["content"]


    if genAI_details["platform"] == "OpenAI":
        client = OpenAI(api_key=os.environ.get('OPENAI_API_KEY'))

        if genAI_details['type'] == 'CoT':
            response = client.chat.completions.create(
                    model=genAI_details["id"],
                    messages = [{
                        "role": "user",
                        "content": label_prompt,
                    }],
                    n=num_labelers      # Get 3 responses simultaneously
                )
            response_text = []
            for choice in response.choices:
                response_text.append(choice.message.content)

        else:
            response = client.chat.completions.create(
                model=genAI_details["id"],
                messages = [{
                    "role": "user",
                    "content": label_prompt,
                }],
                temperature=0.0 # Greedy
            )
            response_text = response.choices[0].message.content

        return response_text

# %% [markdown]
# ### Parse Label Response

# %%
def parse_label_response(response, dataset_details, cot_terminator = None):
    if cot_terminator:      #   Remove the reasoning layer text for Chain-of-Thought models
        response.find(cot_terminator)
        response_start = response.find(cot_terminator)+len(cot_terminator)
        response = response[response_start:]

    #print(response)

    # Find the label that occurs first.
    min_index = float('inf')
    first_found_label = None
    for label in dataset_details["all_labels"]:
        index = response.lower().find(label)
        if index != -1:
            if index < min_index:
                min_index = index
                first_found_label = label

    if first_found_label is None:
        raise ResponseError("Label not found:\n%s", response)

    return first_found_label

# %% [markdown]
# ### Label Record

# %%
def get_label(dataset_details, gen_ai_details, text, event=None):
    label_prompt = build_label_prompt(dataset_details['id'], text, event)

    response = generate_synthetic_label(gen_ai_details, label_prompt, dataset_details['min_labelers'])
    print(response)

    if type(response) == str:
        label = parse_label_response(response, dataset_details, gen_ai_details['terminator'])
        print(f"--------------------------------------------- Label: {label} ---------------------------------------------\n ")
        return label, [label], [response]

    elif type(response) == list:
        response_list = response
        labels = []

        for response in response_list:
            label = parse_label_response(response, dataset_details, gen_ai_details['terminator'])
            labels.append(label)

        consensus_label = dataset_details['unlabeled_label']
        for potential_label in dataset_details["all_labels"]:
            if labels.count(potential_label) >= dataset_details["num_consensus"]:
                consensus_label = potential_label

        print(f"CONSENSUS LABEL: {consensus_label}")
        return consensus_label, labels, response

# %% [markdown]
# # Main Loop

# %%
for dataset in datasets:
    dataset_details = dataset_config[dataset]        #   Get dataset info

    try:
        df_dataset = pd.read_csv(import_location)    #  Load dataset
    except FileNotFoundError:
        df_dataset = pd.DataFrame()

    for ai_model in ai_models:
        ai_details = gen_ai_config.model[ai_model]   #   Get model info

        try:
            df_dataset.insert(len(df_dataset.columns), ai_details['id'], '')    #   Create a new column or clear old data for the AI generated labels

        except ValueError:
            if overwrite_previous_labels is True:
                df_dataset[ai_details['id']] = ''

        if ai_model == 'DeepSeek-R1 14B':
            os.makedirs(os.path.join(export_location, 'ai_responses', ai_model), exist_ok=True)

        for df_index, row in df_dataset.iterrows():
            print(f'{ai_model} -> {df_index}')
            successful = False

            while not successful:
                try:
                    if 'context' in df_dataset.columns:
                        label, labels, responses = get_label(dataset_details, ai_details, row.text, row.context)
                    else:
                        label, labels, responses = get_label(dataset_details, ai_details, row.text)

                except ResponseError:  #   Recover from a CUDA illegal memory access error
                    from time import sleep
                    sleep(5)

                else:
                    df_dataset.at[df_index, ai_details['id']] = label

                    if ai_model == 'DeepSeek-R1 14B':
                        with open(os.path.join(export_location,'ai_responses', ai_model, f"{dataset_details['id']}_{df_index}.txt"), 'w', encoding="utf-8") as file:
                            file.write(f"Record: \"{df_dataset['text'].iloc[df_index]}\"\n{ai_model}\n{'-'*120}\n\n")
                            for response_index, line in enumerate(responses):
                                file.write(f"Response {response_index+1}:\n{line}\n{'-'*120}\n\n")

                    successful = True

        display(df_dataset)
        df_dataset.to_csv(os.path.join(export_location, export_name), index_label=False)
# Out:
# Llama3.1 8B instruct-q8 -> 0
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 1
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 2
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 3
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 4
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 5
# fear
# --------------------------------------------- Label: fear ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 6
# surprise
# --------------------------------------------- Label: surprise ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 7
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 8
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 9
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 10
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 11
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 12
# disgust
# --------------------------------------------- Label: disgust ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 13
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 14
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 15
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 16
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 17
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 18
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 19
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 20
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 21
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 22
# fear
# --------------------------------------------- Label: fear ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 23
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 24
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 25
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 26
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 27
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 28
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 29
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 30
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 31
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 32
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 33
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 34
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 35
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 36
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 37
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 38
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 39
# surprise
# --------------------------------------------- Label: surprise ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 40
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 41
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 42
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 43
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 44
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 45
# disgust
# --------------------------------------------- Label: disgust ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 46
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 47
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 48
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 49
# surprise
# --------------------------------------------- Label: surprise ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 50
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 51
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 52
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 53
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 54
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 55
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 56
# disgust
# --------------------------------------------- Label: disgust ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 57
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 58
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 59
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 60
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 61
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 62
# disgust
# --------------------------------------------- Label: disgust ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 63
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 64
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 65
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 66
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 67
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 68
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 69
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 70
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 71
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 72
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 73
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 74
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 75
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 76
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 77
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 78
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 79
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 80
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 81
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 82
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 83
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 84
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 85
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 86
# fear
# --------------------------------------------- Label: fear ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 87
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 88
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 89
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 90
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 91
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 92
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 93
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 94
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 95
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 96
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 97
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 98
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 99
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 100
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 101
# disgust
# --------------------------------------------- Label: disgust ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 102
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 103
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 104
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 105
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 106
# disgust
# --------------------------------------------- Label: disgust ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 107
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 108
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 109
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 110
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 111
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 112
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 113
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 114
# sadness
# --------------------------------------------- Label: sadness ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 115
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 116
# joy
# --------------------------------------------- Label: joy ---------------------------------------------
#
# Llama3.1 8B instruct-q8 -> 117
# anger
# --------------------------------------------- Label: anger ---------------------------------------------
#
# Llama3.1 8B instruct-q8 ->
# ['fear', 'fear', 'fear']
# CONSENSUS LABEL: fear
# o3-mini -> 268
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 269
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 270
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 271
# ['surprise', 'surprise', 'surprise']
# CONSENSUS LABEL: surprise
# o3-mini -> 272
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 273
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 274
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 275
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 276
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 277
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 278
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 279
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 280
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 281
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 282
# ['surprise', 'anger', 'surprise']
# CONSENSUS LABEL: surprise
# o3-mini -> 283
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 284
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 285
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 286
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 287
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 288
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 289
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 290
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 291
# ['fear', 'fear', 'fear']
# CONSENSUS LABEL: fear
# o3-mini -> 292
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 293
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 294
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 295
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 296
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 297
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 298
# ['anger', 'fear', 'fear']
# CONSENSUS LABEL: fear
# o3-mini -> 299
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 300
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 301
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 302
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 303
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 304
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 305
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 306
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 307
# ['sadness', 'disgust', 'disgust']
# CONSENSUS LABEL: disgust
# o3-mini -> 308
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 309
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 310
# ['joy', 'sadness', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 311
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 312
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 313
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 314
# ['joy', 'surprise', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 315
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 316
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 317
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 318
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 319
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 320
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 321
# ['sadness', 'sadness', 'anger']
# CONSENSUS LABEL: sadness
# o3-mini -> 322
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 323
# ['joy', 'surprise', 'surprise']
# CONSENSUS LABEL: surprise
# o3-mini -> 324
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 325
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 326
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 327
# ['fear', 'fear', 'fear']
# CONSENSUS LABEL: fear
# o3-mini -> 328
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 329
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 330
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 331
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 332
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 333
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 334
# ['surprise', 'surprise', 'anger']
# CONSENSUS LABEL: surprise
# o3-mini -> 335
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 336
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 337
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 338
# ['fear', 'fear', 'fear']
# CONSENSUS LABEL: fear
# o3-mini -> 339
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 340
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 341
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 342
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 343
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 344
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 345
# ['surprise', 'surprise', 'surprise']
# CONSENSUS LABEL: surprise
# o3-mini -> 346
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 347
# ['fear', 'fear', 'fear']
# CONSENSUS LABEL: fear
# o3-mini -> 348
# ['joy', 'surprise', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 349
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 350
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 351
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 352
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 353
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 354
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 355
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 356
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 357
# ['fear', 'fear', 'fear']
# CONSENSUS LABEL: fear
# o3-mini -> 358
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 359
# ['surprise', 'surprise', 'fear']
# CONSENSUS LABEL: surprise
# o3-mini -> 360
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 361
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 362
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 363
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 364
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 365
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 366
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 367
# ['anger', 'anger', 'disgust']
# CONSENSUS LABEL: anger
# o3-mini -> 368
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 369
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 370
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 371
# ['fear', 'fear', 'fear']
# CONSENSUS LABEL: fear
# o3-mini -> 372
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 373
# ['disgust', 'surprise', 'anger']
# CONSENSUS LABEL: others
# o3-mini -> 374
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 375
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 376
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 377
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 378
# ['surprise', 'surprise', 'surprise']
# CONSENSUS LABEL: surprise
# o3-mini -> 379
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 380
# ['surprise', 'surprise', 'surprise']
# CONSENSUS LABEL: surprise
# o3-mini -> 381
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 382
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 383
# ['joy', 'surprise', 'surprise']
# CONSENSUS LABEL: surprise
# o3-mini -> 384
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 385
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 386
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 387
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 388
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 389
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 390
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 391
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 392
# ['sadness', 'sadness', 'sadness']
# CONSENSUS LABEL: sadness
# o3-mini -> 393
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 394
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 395
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 396
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 397
# ['anger', 'anger', 'anger']
# CONSENSUS LABEL: anger
# o3-mini -> 398
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
# o3-mini -> 399
# ['joy', 'joy', 'joy']
# CONSENSUS LABEL: joy
#      original index          context  \
# 0              4183  ChampionsLeague
# 1              2733     WorldBookDay
# 2               197        NotreDame
# 3              3519    GretaThunberg
# 4               912  ChampionsLeague
# ..              ...              ...
# 395            3956    GameOfThrones
# 396            5607     WorldBookDay
# 397            1635        NotreDame
# 398             335  ChampionsLeague
# 399             934     WorldBookDay
#
#                                                   text   labels  \
# 0    Love that Jurgen just told the boys to smile a...      joy
# 1    #WorldBookDay To some amazing books that have ...      joy
# 2    I know it’s been over 24 hours and for some re...  sadness
# 3    Educating for Extinction. (climate change as a...      joy
# 4    I hope Salah scores a hat trick in the second ...      joy
# ..                                                 ...      ...
# 395  I’ve watched episode 3, the battle for winterf...      joy
# 396  "I do believe something very magical can happe...      joy
# 397  What we know so far about the #NotreDameCathed...     fear
# 398  Year 2030 Me: Anyone remember 2019 when Liverp...  disgust
# 399  Book lover? From beach libraries and charming ...      joy
#
#     llama3.1:8b-instruct-q8_0 deepseek-r1:14b gpt-4o-mini  o3-mini
# 0                         joy             joy         joy      joy
# 1                         joy             joy         joy      joy
# 2                     sadness         sadness     sadness  sadness
# 3                       anger         sadness     disgust    anger
# 4                         joy             joy         joy      joy
# ..                        ...             ...         ...      ...
# 395                       joy             joy         joy      joy
# 396                       joy             joy         joy      joy
# 397                     anger           anger       anger    anger
# 398                     anger             joy     sadness      joy
# 399                       joy             joy         joy      joy
#
# [400 rows x 8 columns]

# %% [markdown]
# # Testing

# %% [markdown]
# for dataset in datasets:
#     dataset_details = dataset_config[dataset]               #   Get dataset info
#     df_dataset = pd.read_csv(dataset_details['relpath'])    #  Load dataset
#
#     for ai_model in ['DeepSeek-R1 14B']:
#         ai_details = gen_ai_config.model[ai_model]                          #   Get model info
#         df_dataset.insert(len(df_dataset.columns), ai_details['id'], '')    #   Create a new column or clear old data for the AI generated labels
#         for row in df_dataset.itertuples():
#             print(get_label(dataset_details, ai_details, row.text, row.event)[1])
#         #if 'event' in df_dataset.columns:
#         #    df_dataset[ai_details['id']] = df_dataset.apply(lambda row: get_label(dataset_details, ai_details, row.text, row.event)[1], axis=1)
#         #else:
#         #    df_dataset[ai_details['id']] = df_dataset.apply(lambda row: get_label(dataset_details, ai_details, row['text'])[1])
# #

# %%
df_dataset.to_csv(os.path.join(export_location, export_name), index_label=False)

df_dataset
# Out:
#      original index          context  \
# 0              4183  ChampionsLeague
# 1              2733     WorldBookDay
# 2               197        NotreDame
# 3              3519    GretaThunberg
# 4               912  ChampionsLeague
# ..              ...              ...
# 395            3956    GameOfThrones
# 396            5607     WorldBookDay
# 397            1635        NotreDame
# 398             335  ChampionsLeague
# 399             934     WorldBookDay
#
#                                                   text   labels  \
# 0    Love that Jurgen just told the boys to smile a...      joy
# 1    #WorldBookDay To some amazing books that have ...      joy
# 2    I know it’s been over 24 hours and for some re...  sadness
# 3    Educating for Extinction. (climate change as a...      joy
# 4    I hope Salah scores a hat trick in the second ...      joy
# ..                                                 ...      ...
# 395  I’ve watched episode 3, the battle for winterf...      joy
# 396  "I do believe something very magical can happe...      joy
# 397  What we know so far about the #NotreDameCathed...     fear
# 398  Year 2030 Me: Anyone remember 2019 when Liverp...  disgust
# 399  Book lover? From beach libraries and charming ...      joy
#
#     llama3.1:8b-instruct-q8_0 deepseek-r1:14b gpt-4o-mini  o3-mini
# 0                         joy             joy         joy      joy
# 1                         joy             joy         joy      joy
# 2                     sadness         sadness     sadness  sadness
# 3                       anger         sadness     disgust    anger
# 4                         joy             joy         joy      joy
# ..                        ...             ...         ...      ...
# 395                       joy             joy         joy      joy
# 396                       joy             joy         joy      joy
# 397                     anger           anger       anger    anger
# 398                     anger             joy     sadness      joy
# 399                       joy             joy         joy      joy
#
# [400 rows x 8 columns]

# %%
df_dataset.at[89, 'deepseek-r1:14b'] = 'other'
