# %% [markdown]
# # Config

# %%
import_location = 'datasets/goemotions/ekman_6_single_label/poc_subset/ai_labeled/goemotions_6_single_poc_ai_labeled.csv'
export_location = 'datasets/goemotions/ekman_6_single_label/poc_subset/ai_labeled/goemotions_6_single_poc_ai_labeled.csv'

datasets = ['GoEmotions POC']
ai_models = ['GPT 4o-mini', 'o1-mini'] # 'Llama3.1 8B instruct-q8', 'DeepSeek-R1 14B', 'GPT 4o-mini', 'o3-mini'
overwrite_previous_labels = False

sample_size = 50
random_seed = 418   #   I'm a teacup

from config_files.dataset_config import dataset as dataset_config
from config_files import gen_ai_config

# %%
import pandas as pd
import os
import ollama
from ollama import ResponseError
from openai import OpenAI

# %% [markdown]
# # Label Generation Functions

# %% [markdown]
# ### Build Label Prompt

# %%
def build_label_prompt(dataset_id, text, ai_model, event = None):
    from config_files import prompts

    prompt = prompts.prompt[dataset_id]['labels'].replace('<text>', text)

    # Get some "thinking" if not deepseek
    if ai_model[:8] == 'deepseek':
        response_instructions = prompts.prompt[dataset_id]['Deepseek']
    else:
        response_instructions = prompts.prompt[dataset_id]['GPT']

    prompt = prompt.replace('<response instructions>', response_instructions)

    # Add context for EmoEvent
    if event:
        prompt = prompt.replace('<context>', prompts.prompt[dataset_id]['context'][event])
    else:
        prompt = prompt.replace('<context>', "")

    return prompt

# %% [markdown]
# ### Generate AI Label

# %%
def generate_synthetic_label(dataset_details, genAI_details, label_prompt):
    if genAI_details["platform"] == "Ollama":
        response = ollama.chat(
            model=genAI_details["id"],
            messages=[{
                "role": "user",
                "content": label_prompt
            }]
        )

        return response["message"]["content"]

    elif genAI_details["platform"] == "OpenAI":
        client = OpenAI(api_key=os.environ.get('OPENAI_API_KEY'))

        response = client.chat.completions.create(
            model=genAI_details["id"],
            messages = [{
                "role": "user",
                "content": label_prompt,
            }],
            n=dataset_details["num_labelers"]
        )

        response_text = []
        for choice in response.choices:
            response_text.append(choice.message.content)

        return response_text

# %% [markdown]
# ### Parse Label Response

# %%
def parse_label_response(response, dataset_details, cot_terminator = None):
    if cot_terminator:      #   Remove the reasoning layer text for Chain-of-Thought models
        response.find(cot_terminator)
        response = response[response.find(cot_terminator):]

    for label in dataset_details["label_list"]:
        if f'**{label.lower()}**' in response.lower():
            return label
        elif f'{label.lower()}' in response.lower():
            return label

    # # Label name not found, look for ID number
    # for i in range(1, len(dataset_details["label_list"]) + 1):
    #     if str(i) in response:
    #         return dataset_details["label_list"][i-1]

    # Label not found
    CRED = '\33[91m'
    CEND = '\33[0m'
    print(f"{CRED}NO LABEL FOUND:{CEND} {response}")
    return None

# %% [markdown]
# ### Label Record

# %%
def get_label(dataset_details, gen_ai_details, text, event=None):
    label_prompt = build_label_prompt(dataset_details['id'], text, gen_ai_details['id'], event)

    labels = []
    responses = []
    print("Labels: ", end="")
    if gen_ai_details['platform'] == "Ollama":

        for i in range(dataset_details['num_labelers']):
            label_response = generate_synthetic_label(dataset_details, gen_ai_details, label_prompt)
            responses.append(label_response)
            labels.append(parse_label_response(label_response, dataset_details, gen_ai_details['terminator']))

            if i > 0:
                print(", ", end="")
            print(f"{labels[i]}", end="")
        print()

    elif gen_ai_details['platform'] == "OpenAI":
        responses = generate_synthetic_label(dataset_details, gen_ai_details, label_prompt)
        for i, response in enumerate(responses):
            labels.append(parse_label_response(response, dataset_details))

            if i > 0:
                print(", ", end="")
            print(f"{labels[i]}", end="")

    consensus_label = None

    if dataset_details["label_format"] == "single":
        # Single label dataset
        for potential_label in dataset_details["label_list"]:
            if labels.count(potential_label) >= dataset_details["num_consensus"]:
                consensus_label = potential_label
        print(f"\n\tConsensus: {consensus_label}\n")

    elif dataset_details["label_format"] == "multi":
        # To be implemented if used with any multilabel datasets
        pass

    return consensus_label, labels, responses

# %% [markdown]
# # Main Loop

# %%
for dataset in datasets:
    dataset_details = dataset_config[dataset]               #   Get dataset info
    df_dataset = pd.read_csv(import_location)    #  Load dataset

    for ai_model in ai_models:
        ai_details = gen_ai_config.model[ai_model]                          #   Get model info

        if overwrite_previous_labels is False and ai_details['id'] in df_dataset.columns:
            continue

        try:
            df_dataset.insert(len(df_dataset.columns), ai_details['id'], '')    #   Create a new column or clear old data for the AI generated labels

        except ValueError:
            if overwrite_previous_labels is True:
                df_dataset[ai_details['id']] = ''

        os.makedirs(f'datasets/goemotions/ekman_6_single_label/poc_subset/ai_labeled/ai_responses/{ai_model}/', exist_ok=True)

        for df_index, row in df_dataset.iterrows():
            print(df_index)
            successful = False
            with open(f'datasets/goemotions/ekman_6_single_label/poc_subset/ai_labeled/ai_responses/{ai_model}/{dataset_details['id']}_{df_index}.txt', 'w', encoding="utf-8") as file:
                while not successful:
                    try:
                        if 'context' in df_dataset.columns:
                            label, labels, responses = get_label(dataset_details, ai_details, row.text, row.event)
                        else:
                            label, labels, responses = get_label(dataset_details, ai_details, row.text)

                    except ResponseError:  #   Recover from a CUDA illegal memory access error
                        from time import sleep
                        sleep(5)

                    else:
                        df_dataset.at[df_index, ai_details['id']] = label
                        file.write(f"Record: \"{df_dataset['text'].iloc[df_index]}\"\n{ai_model}\n{'-'*120}\n\n")
                        for response_index, line in enumerate(responses):
                            file.write(f"Response {response_index+1}:\n{line}\n{'-'*120}\n\n")
                        successful = True

        display(df_dataset)
# Out:
# Labels: joy, joy, anger
# 	Consensus: joy
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: fear, neutral, neutral
# 	Consensus: neutral
#
# Labels: fear, joy, fear
# 	Consensus: fear
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: anger, sadness, anger
# 	Consensus: anger
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: disgust, disgust, disgust
# 	Consensus: disgust
#
# Labels: neutral, surprise, neutral
# 	Consensus: neutral
#
# Labels: anger, sadness, sadness
# 	Consensus: sadness
#
# Labels: anger, disgust, disgust
# 	Consensus: disgust
#
# Labels: neutral, anger, anger
# 	Consensus: anger
#
# Labels: joy, anger, joy
# 	Consensus: joy
#
# Labels: fear, surprise, anger
# 	Consensus: None
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: disgust, disgust, anger
# 	Consensus: disgust
#
# Labels: anger, disgust, anger
# 	Consensus: anger
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: disgust, anger, anger
# 	Consensus: anger
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: anger, anger, disgust
# 	Consensus: anger
#
# Labels: anger, neutral, joy
# 	Consensus: None
#
# Labels: anger, neutral, anger
# 	Consensus: anger
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: anger, anger, fear
# 	Consensus: anger
#
# Labels: anger, sadness, surprise
# 	Consensus: None
#
# Labels: anger, surprise, surprise
# 	Consensus: surprise
#
# Labels: surprise, surprise, surprise
# 	Consensus: surprise
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: anger, anger, fear
# 	Consensus: anger
#
# Labels: neutral, anger, surprise
# 	Consensus: None
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: neutral, neutral, anger
# 	Consensus: neutral
#
# Labels: fear, neutral, neutral
# 	Consensus: neutral
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: surprise, neutral, anger
# 	Consensus: None
#
# Labels: anger, anger, anger
# 	Consensus: anger
#
# Labels: disgust, anger, disgust
# 	Consensus: disgust
#
# Labels: joy, joy, joy
# 	Consensus: joy
#
# Labels: sadness, sadness, disgust
# 	Consensus: sadness
#
# Labels: anger, anger, fear
# 	Consensus: anger
#
# Labels: fear, fear, fear
# 	Consensus: fear
#
# Labels: joy, joy, joy
# 	Consensus: joy
#     Unnamed: 0    labels                                               text  \
# 0         6232      love  I love it. Probably my favorite game mode righ...
# 1        30473       joy  Those are some interesting stats. I’m gonna sa...
# 2        43446   neutral   Justified or not he'll probably go before [NAME]
# 3        23954   neutral  If I'm no good I can still give the 1st round ...
# 4        24657       joy  At least it made for hilarious responses by pe...
# 5        25589   neutral  "qt 3.14" made me retreat into my own face, so...
# 6        27710       joy  This one is by [NAME]! Your suggestion was fun...
# 7        46841   neutral  Assuming you're a dude, yes, just let him watc...
# 8        11235   neutral  Grew up in an early 90's house with door handl...
# 9         1634   neutral  I see your "making myself undateable" and rais...
# 10       29937   disgust  Take a shower brother, i can smell you through...
# 11       36624     anger  New word for me: tetch·y /ˈteCHē/ adjective ba...
# 12       18851       joy                               Ah what a good start
# 13       38457     anger  The Birds is probably not quite what you are e...
# 14       42681   neutral  Now you're lying. Suburbs = more than Bellevue...
# 15       11766     anger  Maybe unpopular but I never eat pancakes with ...
# 16       15235   sadness    Your life must be miserable. That's sad somehow
# 17       25444   neutral  That's definitely way over the top. He's not a...
# 18       27546       joy  Well that makes it easy. Thanks again. I'll lo...
# 19         331      love  Their orange chicken is the absolute fucking b...
# 20        9383   neutral                    Ah yes, the true third gender.
# 21       21985       joy           Thank u!!! Im gonna try this one bless u
# 22       37654   sadness            Ya it’s Bamas league to lose every year
# 23       24030     anger  I solo climbed to Master as main DPS with 60hz...
# 24       15723       joy  Sorry but why does it matter that you're "from...
# 25       16728       joy  well guys it was fun. [NAME] passed up the ope...
# 26       13583       joy                                      [NAME] YES!!!
# 27       36124   neutral                                       Spicy water.
# 28       13567   neutral  She tried playing the “I know a secret” game d...
# 29       17786  surprise  Is that his thing? (I honestly don't know what...
# 30        6995  surprise                               Wow, that was insane
# 31       38626       joy  The internationalist EU. The [NAME], [NAME], [...
# 32        4209       joy                       I enjoyed speaking to [NAME]
# 33       36891   neutral                               Just a friend, chill
# 34       44782   neutral              That’s exactly how my fanfiction goes
# 35        8620     anger  No, there’s a ton of people like you in this t...
# 36       18571  surprise                   I don't know who is dumber here.
# 37       11330   neutral  350 calories The large is 20 oz and it’s 140 p...
# 38       17158  surprise  Very interesting to find out about small detai...
# 39       30539       joy  I skipped the Oilers game for a birthday party...
# 40       13845   sadness  These leaks are actually very credible. It's s...
# 41       10987   neutral  Here. I didn’t delete it, but rather changed m...
# 42        4625       joy             Bears are empathetic creatures? lol...
# 43        5054      fear                               What a terrible list
# 44        5928       joy  I’m gonna need a couple more checks before I t...
# 45       36022       joy                               Underrated comment 🤣
# 46       11374  surprise  Bleak but may be accurate. I wonder - are ther...
# 47        3710   neutral  *police proceed to slide down hill* *I quickly...
# 48       10291       joy  Absolutely you are doing the right thing. She ...
# 49       42500       joy  Right now I’d have to say [NAME] new restauran...
#
#    llama3.1:8b-instruct-q8_0 deepseek-r1:14b gpt-4o-mini  o3-mini   o1-mini
# 0                        joy             joy         joy      NaN       joy
# 1                    neutral             joy       anger      NaN       joy
# 2                        NaN         neutral       anger      NaN   neutral
# 3                        NaN         neutral       anger      NaN      fear
# 4                        joy             joy         joy      NaN       joy
# 5                    disgust         disgust     disgust      NaN     anger
# 6                        joy             joy         joy      NaN       joy
# 7                    neutral         neutral       anger      NaN   disgust
# 8                    neutral         neutral       anger      NaN   neutral
# 9                        joy         sadness     sadness      NaN   sadness
# 10                   disgust         disgust       anger      NaN   disgust
# 11                   neutral           anger       anger      NaN     anger
# 12                     anger             joy         joy      NaN       joy
# 13                     anger         neutral       anger      NaN      None
# 14                     anger           anger       anger      NaN     anger
# 15                   disgust         disgust     disgust      NaN   disgust
# 16                   sadness         sadness     sadness      NaN     anger
# 17                     anger         neutral       anger      NaN     anger
# 18                   neutral             joy       anger      NaN       joy
# 19                       joy             joy         joy      NaN       joy
# 20                   neutral         neutral       anger      NaN     anger
# 21                       joy             joy         joy      NaN       joy
# 22                     anger           anger       anger      NaN     anger
# 23                     anger         neutral       anger      NaN      None
# 24                       NaN         neutral         NaN      NaN     anger
# 25                     anger         neutral       anger      NaN     anger
# 26                       joy             joy         joy      NaN       joy
# 27                     anger         neutral     disgust      NaN     anger
# 28                     anger         neutral       anger      NaN      None
# 29                       NaN         neutral       anger      NaN  surprise
# 30                     anger        surprise    surprise      NaN  surprise
# 31                   disgust             joy       anger      NaN       joy
# 32                       joy             joy         joy      NaN     anger
# 33                     anger         neutral       anger      NaN     anger
# 34                       NaN         neutral       anger      NaN      None
# 35                     anger           anger       anger      NaN     anger
# 36                     anger           anger       anger      NaN     anger
# 37                   neutral         neutral     neutral      NaN   neutral
# 38                   neutral             joy       anger      NaN   neutral
# 39                       joy             joy         joy      NaN       joy
# 40                     anger         sadness       anger      NaN     anger
# 41                     anger         neutral     neutral      NaN     anger
# 42                       NaN             joy         NaN      NaN      None
# 43                     anger         disgust       anger      NaN     anger
# 44                     anger           anger     disgust      NaN   disgust
# 45                       joy             joy         joy      NaN       joy
# 46                     anger         sadness     sadness      NaN   sadness
# 47                     anger         neutral         NaN      NaN     anger
# 48                      fear            fear         NaN      NaN      fear
# 49                       joy             joy         joy      NaN       joy

# %% [markdown]
# # Testing

# %% [markdown]
# for dataset in datasets:
#     dataset_details = dataset_config[dataset]               #   Get dataset info
#     df_dataset = pd.read_csv(dataset_details['relpath'])    #  Load dataset
#
#     for ai_model in ['DeepSeek-R1 14B']:
#         ai_details = gen_ai_config.model[ai_model]                          #   Get model info
#         df_dataset.insert(len(df_dataset.columns), ai_details['id'], '')    #   Create a new column or clear old data for the AI generated labels
#         for row in df_dataset.itertuples():
#             print(get_label(dataset_details, ai_details, row.text, row.event)[1])
#         #if 'event' in df_dataset.columns:
#         #    df_dataset[ai_details['id']] = df_dataset.apply(lambda row: get_label(dataset_details, ai_details, row.text, row.event)[1], axis=1)
#         #else:
#         #    df_dataset[ai_details['id']] = df_dataset.apply(lambda row: get_label(dataset_details, ai_details, row['text'])[1])
# #

# %%
df_dataset.to_csv(export_location, index_label=False)

df_dataset
# Out:
#     Unnamed: 0    labels                                               text  \
# 0         6232      love  I love it. Probably my favorite game mode righ...
# 1        30473       joy  Those are some interesting stats. I’m gonna sa...
# 2        43446   neutral   Justified or not he'll probably go before [NAME]
# 3        23954   neutral  If I'm no good I can still give the 1st round ...
# 4        24657       joy  At least it made for hilarious responses by pe...
# 5        25589   neutral  "qt 3.14" made me retreat into my own face, so...
# 6        27710       joy  This one is by [NAME]! Your suggestion was fun...
# 7        46841   neutral  Assuming you're a dude, yes, just let him watc...
# 8        11235   neutral  Grew up in an early 90's house with door handl...
# 9         1634   neutral  I see your "making myself undateable" and rais...
# 10       29937   disgust  Take a shower brother, i can smell you through...
# 11       36624     anger  New word for me: tetch·y /ˈteCHē/ adjective ba...
# 12       18851       joy                               Ah what a good start
# 13       38457     anger  The Birds is probably not quite what you are e...
# 14       42681   neutral  Now you're lying. Suburbs = more than Bellevue...
# 15       11766     anger  Maybe unpopular but I never eat pancakes with ...
# 16       15235   sadness    Your life must be miserable. That's sad somehow
# 17       25444   neutral  That's definitely way over the top. He's not a...
# 18       27546       joy  Well that makes it easy. Thanks again. I'll lo...
# 19         331      love  Their orange chicken is the absolute fucking b...
# 20        9383   neutral                    Ah yes, the true third gender.
# 21       21985       joy           Thank u!!! Im gonna try this one bless u
# 22       37654   sadness            Ya it’s Bamas league to lose every year
# 23       24030     anger  I solo climbed to Master as main DPS with 60hz...
# 24       15723       joy  Sorry but why does it matter that you're "from...
# 25       16728       joy  well guys it was fun. [NAME] passed up the ope...
# 26       13583       joy                                      [NAME] YES!!!
# 27       36124   neutral                                       Spicy water.
# 28       13567   neutral  She tried playing the “I know a secret” game d...
# 29       17786  surprise  Is that his thing? (I honestly don't know what...
# 30        6995  surprise                               Wow, that was insane
# 31       38626       joy  The internationalist EU. The [NAME], [NAME], [...
# 32        4209       joy                       I enjoyed speaking to [NAME]
# 33       36891   neutral                               Just a friend, chill
# 34       44782   neutral              That’s exactly how my fanfiction goes
# 35        8620     anger  No, there’s a ton of people like you in this t...
# 36       18571  surprise                   I don't know who is dumber here.
# 37       11330   neutral  350 calories The large is 20 oz and it’s 140 p...
# 38       17158  surprise  Very interesting to find out about small detai...
# 39       30539       joy  I skipped the Oilers game for a birthday party...
# 40       13845   sadness  These leaks are actually very credible. It's s...
# 41       10987   neutral  Here. I didn’t delete it, but rather changed m...
# 42        4625       joy             Bears are empathetic creatures? lol...
# 43        5054      fear                               What a terrible list
# 44        5928       joy  I’m gonna need a couple more checks before I t...
# 45       36022       joy                               Underrated comment 🤣
# 46       11374  surprise  Bleak but may be accurate. I wonder - are ther...
# 47        3710   neutral  *police proceed to slide down hill* *I quickly...
# 48       10291       joy  Absolutely you are doing the right thing. She ...
# 49       42500       joy  Right now I’d have to say [NAME] new restauran...
#
#    llama3.1:8b-instruct-q8_0 deepseek-r1:14b gpt-4o-mini  o3-mini   o1-mini
# 0                        joy             joy         joy      NaN       joy
# 1                    neutral             joy       anger      NaN       joy
# 2                        NaN         neutral       anger      NaN   neutral
# 3                        NaN         neutral       anger      NaN      fear
# 4                        joy             joy         joy      NaN       joy
# 5                    disgust         disgust     disgust      NaN     anger
# 6                        joy             joy         joy      NaN       joy
# 7                    neutral         neutral       anger      NaN   disgust
# 8                    neutral         neutral       anger      NaN   neutral
# 9                        joy         sadness     sadness      NaN   sadness
# 10                   disgust         disgust       anger      NaN   disgust
# 11                   neutral           anger       anger      NaN     anger
# 12                     anger             joy         joy      NaN       joy
# 13                     anger         neutral       anger      NaN      None
# 14                     anger           anger       anger      NaN     anger
# 15                   disgust         disgust     disgust      NaN   disgust
# 16                   sadness         sadness     sadness      NaN     anger
# 17                     anger         neutral       anger      NaN     anger
# 18                   neutral             joy       anger      NaN       joy
# 19                       joy             joy         joy      NaN       joy
# 20                   neutral         neutral       anger      NaN     anger
# 21                       joy             joy         joy      NaN       joy
# 22                     anger           anger       anger      NaN     anger
# 23                     anger         neutral       anger      NaN      None
# 24                       NaN         neutral         NaN      NaN     anger
# 25                     anger         neutral       anger      NaN     anger
# 26                       joy             joy         joy      NaN       joy
# 27                     anger         neutral     disgust      NaN     anger
# 28                     anger         neutral       anger      NaN      None
# 29                       NaN         neutral       anger      NaN  surprise
# 30                     anger        surprise    surprise      NaN  surprise
# 31                   disgust             joy       anger      NaN       joy
# 32                       joy             joy         joy      NaN     anger
# 33                     anger         neutral       anger      NaN     anger
# 34                       NaN         neutral       anger      NaN      None
# 35                     anger           anger       anger      NaN     anger
# 36                     anger           anger       anger      NaN     anger
# 37                   neutral         neutral     neutral      NaN   neutral
# 38                   neutral             joy       anger      NaN   neutral
# 39                       joy             joy         joy      NaN       joy
# 40                     anger         sadness       anger      NaN     anger
# 41                     anger         neutral     neutral      NaN     anger
# 42                       NaN             joy         NaN      NaN      None
# 43                     anger         disgust       anger      NaN     anger
# 44                     anger           anger     disgust      NaN   disgust
# 45                       joy             joy         joy      NaN       joy
# 46                     anger         sadness     sadness      NaN   sadness
# 47                     anger         neutral         NaN      NaN     anger
# 48                      fear            fear         NaN      NaN      fear
# 49                       joy             joy         joy      NaN       joy
