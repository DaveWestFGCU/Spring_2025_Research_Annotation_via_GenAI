# %%
import pandas as pd

import_location = './goemotions_labels.csv'
df = pd.read_csv(import_location)

df = df.rename(columns={'crowdsourced (original)': 'crowdsourced'})
df
# Out:
#     Unnamed: 0  original index  \
# 0            0            6232
# 1            1           30473
# 2            2           43446
# 3            3           23954
# 4            4           24657
# 5            5           25589
# 6            6           27710
# 7            7           46841
# 8            8           11235
# 9            9            1634
# 10          10           29937
# 11          11           36624
# 12          12           18851
# 13          13           38457
# 14          14           42681
# 15          15           11766
# 16          16           15235
# 17          17           25444
# 18          18           27546
# 19          19             331
# 20          20            9383
# 21          21           21985
# 22          22           37654
# 23          23           24030
# 24          24           15723
# 25          25           16728
# 26          26           13583
# 27          27           36124
# 28          28           13567
# ...

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(df['crowdsourced'], df['FGCU Combined'])
# Out:
# np.float64(0.35770750988142286)

# %%
cohen_kappa_score(df['crowdsourced'], df['AI Combined'])
# Out:
# np.float64(0.5098039215686275)

# %%
cohen_kappa_score(df['FGCU Combined'], df['AI Combined'])
# Out:
# np.float64(0.560761346998536)

# %%
cohen_kappa_score(df['tim'], df['dave'])
# Out:
# np.float64(0.606879606879607)

# %%
cohen_kappa_score(df['dave'], df['crowdsourced'])
# Out:
# np.float64(0.33002481389578164)

# %%
cohen_kappa_score(df['tim'], df['crowdsourced'])
# Out:
# np.float64(0.3052228078581696)

# %%
from scipy.stats import spearmanr
corr, pval = spearmanr(df['dave'], df['tim'])
print("Spearman's correlation coefficient:", corr)
print("p-value:", pval)
# Out:
# Spearman's correlation coefficient: 0.6554406908958887
# p-value: 2.3983312113309867e-07

# %%
corr, pval = spearmanr(df['dave'], df['crowdsourced'])
print("Spearman's correlation coefficient:", corr)
print("p-value:", pval)
# Out:
# Spearman's correlation coefficient: 0.17436670463359125
# p-value: 0.22586572711510872

# %%
corr, pval = spearmanr(df['tim'], df['crowdsourced'])
print("Spearman's correlation coefficient:", corr)
print("p-value:", pval)
# Out:
# Spearman's correlation coefficient: 0.3047937422270227
# p-value: 0.031381245712225274

# %%
corr, pval = spearmanr(df['crowdsourced'], df['FGCU Combined'])
print("Spearman's correlation coefficient:", corr)
print("p-value:", pval)
# Out:
# Spearman's correlation coefficient: 0.2539746739765744
# p-value: 0.07511545504499736

# %%
corr, pval = spearmanr(df['crowdsourced'], df['AI Combined'])
print("Spearman's correlation coefficient:", corr)
print("p-value:", pval)
# Out:
# Spearman's correlation coefficient: 0.2810222777309661
# p-value: 0.048052274068011304

# %%
corr, pval = spearmanr(df['FGCU Combined'], df['AI Combined'])
print("Spearman's correlation coefficient:", corr)
print("p-value:", pval)
# Out:
# Spearman's correlation coefficient: 0.5763557166390003
# p-value: 1.1859543041750918e-05
