# %% [markdown]
# # Config

# %%
import_location = 'ai_labeled/EmoEvents_raw_poc.csv'
export_location = 'ai_labeled/EmoEvents_raw_poc.csv'
overwrite_previous_labels = False

datasets = ['Proof of Concept Subset']
ai_models = ['Llama3.1 8B instruct-q8', 'DeepSeek-R1 14B', 'GPT 4o-Mini', 'o1-Mini']

remove_others = True

sample_size = 50
random_seed = 418   #   I'm a teacup

from config_files.dataset_config import dataset as dataset_config
from config_files import gen_ai_config

# %%
import pandas as pd
import os
import ollama
from ollama import ResponseError
from openai import OpenAI

# %% [markdown]
# # Label Generation Functions

# %% [markdown]
# ### Build Label Prompt

# %%
def build_label_prompt(dataset_id, text, event = None):
    from config_files import prompts

    if event:
        intermediate_prompt = prompts.prompt[dataset_id]['labels w/ context'].replace('<text>', text)
        event_context = prompts.prompt[dataset_id]['context'][event]
        final_prompt = intermediate_prompt.replace('<context>', event_context)
    else:
        final_prompt = prompts.prompt[dataset_id]['labels']

    return final_prompt

# %% [markdown]
# ### Generate AI Label

# %%
def generate_synthetic_label(dataset_details, genAI_details, label_prompt):
    if genAI_details["platform"] == "Ollama":
        response = ollama.chat(
            model=genAI_details["id"],
            messages=[{
                "role": "user",
                "content": label_prompt
            }]
        )

        return response["message"]["content"]

    elif genAI_details["platform"] == "OpenAI":
        client = OpenAI(api_key=os.environ.get('OPENAI_API_KEY'))

        response = client.chat.completions.create(
            model=genAI_details["id"],
            messages = [{
                "role": "user",
                "content": label_prompt,
            }],
            n=dataset_details["num_labelers"]
        )

        response_text = []
        for choice in response.choices:
            response_text.append(choice.message.content)

        return response_text

# %% [markdown]
# ### Parse Label Response

# %%
def parse_label_response(response, dataset_details, cot_terminator = None):
    if cot_terminator:      #   Remove the reasoning layer text for Chain-of-Thought models
        response.find(cot_terminator)
        response = response[response.find(cot_terminator):]

    for label in dataset_details["label_list"]:
        if label.lower() in response.lower():
            return label

    # Label name not found, look for ID number
    for i in range(1, len(dataset_details["label_list"]) + 1):
        if str(i) in response:
            return dataset_details["label_list"][i-1]

    # Label not found
    CRED = '\33[91m'
    CEND = '\33[0m'
    print(f"{CRED}NO LABEL FOUND:{CEND} {response}")
    return None

# %% [markdown]
# ### Label Record

# %%
def get_label(dataset_details, gen_ai_details, text, event=None):
    label_prompt = build_label_prompt(dataset_details['id'], text, event)

    labels = []
    responses = []
    print("Labels: ", end="")
    if gen_ai_details['platform'] == "Ollama":

        for i in range(dataset_details['num_labelers']):
            label_response = generate_synthetic_label(dataset_details, gen_ai_details, label_prompt)
            responses.insert(len(responses), label_response)
            labels.append(parse_label_response(label_response, dataset_details, gen_ai_details['terminator']))

            if i > 0:
                print(", ", end="")
            print(f"{labels[i]}", end="")

    elif gen_ai_details['platform'] == "OpenAI":
        responses = generate_synthetic_label(dataset_details, gen_ai_details, label_prompt)
        for i, response in enumerate(responses):
            labels.append(parse_label_response(response, dataset_details))

            if i > 0:
                print(", ", end="")
            print(f"{labels[i]}", end="")

    consensus_label = None

    if dataset_details["label_format"] == "single":
        # Single label dataset
        for potential_label in dataset_details["label_list"]:
            if labels.count(potential_label) >= dataset_details["num_consensus"]:
                consensus_label = potential_label
                print(f"\n\tConsensus: {consensus_label}")

    elif dataset_details["label_format"] == "multi":
        # To be implemented if used with any multilabel datasets
        pass

    return consensus_label, labels, responses

# %% [markdown]
# # Main Loop

# %%
for dataset in datasets:
    dataset_details = dataset_config[dataset]               #   Get dataset info
    df_dataset = pd.read_csv(import_location)    #  Load dataset

    for ai_model in ai_models:
        ai_details = gen_ai_config.model[ai_model]                          #   Get model info

        if overwrite_previous_labels is False and ai_details['id'] in df_dataset.columns:
            continue

        df_dataset.insert(len(df_dataset.columns), ai_details['id'], '')    #   Create a new column or clear old data for the AI generated labels

        os.makedirs(f'./datasets/subset/{ai_model}', exist_ok=True)
        for index, row in df_dataset.iterrows():
            successful = False
            with open(f'./datasets/subset/{ai_model}/{dataset_details['id']}_{index}.txt', 'w', encoding="utf-8") as file:
                while not successful:
                    try:
                        if 'event' in df_dataset.columns:
                            label, labels, responses = get_label(dataset_details, ai_details, row.text, row.event)
                        else:
                            label, labels, responses = get_label(dataset_details, ai_details, row.text)

                    except ResponseError:  #   Recover from a CUDA illegal memory access error
                        from time import sleep
                        sleep(5)

                    else:
                        df_dataset.at[index, ai_details['id']] = label
                        for line in responses:
                            file.write(f"{line}\n")
                        successful = True

        display(df_dataset)
# Out:
# False
# llama3.1:8b-instruct-q8_0
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'event', 'text', 'labels',
#        'deepseek-r1:14b', 'llama3.1:8b-instruct-q8_0', 'gpt-4o-mini'],
#       dtype='object')
# False
# deepseek-r1:14b
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'event', 'text', 'labels',
#        'deepseek-r1:14b', 'llama3.1:8b-instruct-q8_0', 'gpt-4o-mini'],
#       dtype='object')
# False
# gpt-4o-mini
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'event', 'text', 'labels',
#        'deepseek-r1:14b', 'llama3.1:8b-instruct-q8_0', 'gpt-4o-mini'],
#       dtype='object')
# False
# o1-mini
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'event', 'text', 'labels',
#        'deepseek-r1:14b', 'llama3.1:8b-instruct-q8_0', 'gpt-4o-mini'],
#       dtype='object')
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, anger
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, surprise
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: disgust, disgust, disgust
# 	Consensus: disgust
# Labels: anger, anger, anger
# 	Consensus: anger
# Labels: joy, joy, surprise
# 	Consensus: joy
# Labels: anger, anger, anger
# 	Consensus: anger
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: sadness, sadness, sadness
# 	Consensus: sadness
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: anger, disgust, anger
# 	Consensus: anger
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: fear, fear, anger
# 	Consensus: fear
# Labels: sadness, sadness, sadness
# 	Consensus: sadness
# Labels: anger, anger, anger
# 	Consensus: anger
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: anger, disgust, anger
# 	Consensus: anger
# Labels: anger, sadness, anger
# 	Consensus: anger
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: anger, anger, anger
# 	Consensus: anger
# Labels: sadness, sadness, sadness
# 	Consensus: sadness
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: anger, anger, anger
# 	Consensus: anger
# Labels: sadness, sadness, sadness
# 	Consensus: sadness
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: sadness, sadness, sadness
# 	Consensus: sadness
# Labels: anger, anger, anger
# 	Consensus: anger
# Labels: sadness, sadness, sadness
# 	Consensus: sadness
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: anger, disgust, joyLabels: joy, joy, joy
# 	Consensus: joy
# Labels: fear, surprise, fear
# 	Consensus: fear
# Labels: anger, fear, fear
# 	Consensus: fear
# Labels: surprise, surprise, surprise
# 	Consensus: surprise
# Labels: joy, joy, joy
# 	Consensus: joy
# Labels: fear, fear, fear
# 	Consensus: fear
# Labels: sadness, sadness, sadness
# 	Consensus: sadness
#     Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0            event  \
# 0              0             0        3948  ChampionsLeague
# 1              1             1        5636     WorldBookDay
# 2              2             2         507     WorldBookDay
# 3              3             3        5454    GretaThunberg
# 4              4             4        2819  ChampionsLeague
# 5              5             5        5252     WorldBookDay
# 6              6             6         444    GameOfThrones
# 7              7             7        3329     WorldBookDay
# 8              8             8        4879  ChampionsLeague
# 9              9             9        4625    GameOfThrones
# 10            10            10        5315    GretaThunberg
# 11            11            11        4039        Venezuela
# 12            12            12        2958  ChampionsLeague
# 13            13            13        6108    GameOfThrones
# 14            14            14        1019  ChampionsLeague
# 15            15            15        5019        Venezuela
# 16            16            16        7264        NotreDame
# 17            17            17        1950     WorldBookDay
# 18            18            18        7040        NotreDame
# 19            19            19        5709    GameOfThrones
# 20            20            20         558    GretaThunberg
# 21            21            21        6441        Venezuela
# 22            22            22        2859        NotreDame
# 23            23            23        5772        NotreDame
# 24            24            24        6510    GameOfThrones
# 25            25            25        3869        Venezuela
# 26            26            26        3511  ChampionsLeague
# 27            27            27        2814  ChampionsLeague
# 28            28            28        7120     WorldBookDay
# 29            29            29        2279           LaLiga
# 30            30            30         990  ChampionsLeague
# 31            31            31        7083           LaLiga
# 32            32            32          31     WorldBookDay
# 33            33            33        4854     WorldBookDay
# 34            34            34         974     WorldBookDay
# 35            35            35        3152    GameOfThrones
# 36            36            36        6959        NotreDame
# 37            37            37          45    GameOfThrones
# 38            38            38        6559    GameOfThrones
# 39            39            39        1824        Venezuela
# 40            40            40        5744        NotreDame
# 41            41            41        2577    GameOfThrones
# 42            42            42         971  ChampionsLeague
# 43            43            43        4724     WorldBookDay
# 44            44            44        4291        Venezuela
# 45            45            45        1313    GretaThunberg
# 46            46            46        5193    GameOfThrones
# 47            47            47        5930  ChampionsLeague
# 48            48            48        2285        Venezuela
# 49            49            49        2638        Venezuela
#
#                                                  text    labels  \
# 0   Sometimes you just have to admire the genius o...       joy
# 1   If anyone wants to give me a book as a gift, I...       joy
# 2   On #WorldBookDay I am curled up with a book my...       joy
# 3   Very wise words USER_arrowsmith ...we should a...       joy
# 4   FH underway... Hope's to USER #Liverpool to wi...       joy
# 5   Happy world book day from Globeprep! What are ...       joy
# 6   Damn....Game of Thrones sounds crazy! Can’t fo...   disgust
# 7   As we celebrate world book day, make sure to i...       joy
# 8   More #ChampionsLeague action kicking off at 8p...       joy
# 9   That was the best bit of tv I have ever watche...       joy
# 10  Greta Thunberg:  The hero we need, or the resu...   disgust
# 11  #JorgeArreaza President #Trump, so they have t...     anger
# 12  USER been pretty impressive up to now, Mane ha...       joy
# 13  I'm just so angry because my absolute favourit...     anger
# 14  Nobody can make you feel inferior without your...       joy
# 15  FREEDOM for the People of Venezuela 🇻🇪  We are...     anger
# 16  Respect for people in france who've lost a his...   sadness
# 17  There are many little ways to enlarge your chi...       joy
# 18  Billionaires pledging tons of money to fix a c...   disgust
# 19  Wow. Just watched latest episode. Amazing! Tim...       joy
# 20  New translation project! So excited! #scenerur...       joy
# 21  I’ve had CNN in the background most of the day...   disgust
# 22  I am sad about what happened to Notre-Dame bec...   sadness
# 23  The Left: Burn! Burn you symbol of Christian c...     anger
# 24  ARYA OH MY GOD YOU FUCKING BAD ASS BITCH I LOV...       joy
# 25  USER USER USER well, there were plenty of "evi...   disgust
# 26  Didn’t deserve to lose that 3-0, but one team ...       joy
# 27  600 goals for my main man Messi in all competi...       joy
# 28  Happy World Book Day #WorldBookDay 🎶Nwanne Wa ...       joy
# 29                    oh shit now we have 26  #LaLiga  surprise
# 30  Wish my teams were playing in the finals than ...   sadness
# 31  Million Dollar Smile..  GOAT got his 10th Leag...       joy
# 32  On #WorldBookDay, be inspired by these amazing...       joy
# 33  Beloved books 📚. The gateway to history, disco...       joy
# 34  Happy #CanadaBookDay! Only 2 more days to go u...       joy
# 35  The real question we’re now all asking is how ...     anger
# 36  My Gosh 💔💔 Pain in one part of the body ... wh...  surprise
# 37  I actually cried at the end, you all thought a...       joy
# 38  1. we waited 8 seasons before we can finally s...   sadness
# 39  What is happening now in #Venezuela is unaccep...   disgust
# 40  i cry for my brothers in Paris and for those a...   sadness
# 41  Arya is awesome... That's all I have to say......       joy
# 42  Only the 5th best player in the world has gone...   disgust
# 43  #WorldBookDay: Ten memorable scenes from Hindi...   disgust
# 44  Wow! Shits bout to get real folks!  https://t....   disgust
# 45  #GretaThunberg should absolutely be nominated ...      fear
# 46  #Endgame and #GameofThrones both in the one ni...  surprise
# 47  Great ball by Alba, wonderful run &amp; finish...       joy
# 48  What is happening right now in #Venezuela, in ...      fear
# 49  USER What more of a civil war than the rampant...   disgust
#
#    deepseek-r1:14b llama3.1:8b-instruct-q8_0 gpt-4o-mini   o1-mini
# 0              joy                       joy         joy       joy
# 1              joy                       joy         joy       joy
# 2              joy                       joy         joy       joy
# 3              joy                       joy         joy       joy
# 4              joy                       joy         joy       joy
# 5              joy                       joy         joy       joy
# 6         surprise                       joy    surprise       joy
# 7              joy                       joy         joy       joy
# 8              joy                       joy         joy       joy
# 9              joy                       joy         joy       joy
# 10         disgust                     anger     disgust   disgust
# 11           anger                     anger     disgust     anger
# 12        surprise                       joy    surprise       joy
# 13           anger                     anger       anger     anger
# 14             joy                       joy         joy       joy
# 15             joy                       joy         joy       joy
# 16         sadness                   sadness     sadness   sadness
# 17             joy                       joy         joy       joy
# 18           anger                   sadness       anger     anger
# 19             joy                       joy         joy       joy
# 20             joy                       joy         joy       joy
# 21        surprise                     anger        fear      fear
# 22         sadness                   sadness     sadness   sadness
# 23           anger                     anger       anger     anger
# 24             joy                       joy         joy       joy
# 25         disgust                     anger     disgust     anger
# 26         sadness                       joy     sadness     anger
# 27             joy                       joy         joy       joy
# 28             joy                       joy         joy       joy
# 29        surprise                     anger       anger     anger
# 30         sadness                       joy     sadness   sadness
# 31             joy                       joy         joy       joy
# 32             joy                       joy         joy       joy
# 33             joy                       joy         joy       joy
# 34             joy                       joy         joy       joy
# 35        surprise                       joy    surprise     anger
# 36         sadness                   sadness     sadness   sadness
# 37             joy                       joy         joy       joy
# 38         sadness                   sadness     sadness   sadness
# 39           anger                     anger       anger     anger
# 40         sadness                   sadness     sadness   sadness
# 41             joy                       joy         joy       joy
# 42        surprise                       joy         joy      None
# 43             joy                       joy         joy       joy
# 44        surprise                       NaN    surprise      fear
# 45            fear                       NaN         joy      fear
# 46        surprise                       joy         joy  surprise
# 47             joy                       joy         joy       joy
# 48            fear                       NaN        fear      fear
# 49         sadness                     anger       anger   sadness

# %% [markdown]
# # Testing

# %% [markdown]
# for dataset in datasets:
#     dataset_details = dataset_config[dataset]               #   Get dataset info
#     df_dataset = pd.read_csv(dataset_details['relpath'])    #  Load dataset
#
#     for ai_model in ['DeepSeek-R1 14B']:
#         ai_details = gen_ai_config.model[ai_model]                          #   Get model info
#         df_dataset.insert(len(df_dataset.columns), ai_details['id'], '')    #   Create a new column or clear old data for the AI generated labels
#         for row in df_dataset.itertuples():
#             print(get_label(dataset_details, ai_details, row.text, row.event)[1])
#         #if 'event' in df_dataset.columns:
#         #    df_dataset[ai_details['id']] = df_dataset.apply(lambda row: get_label(dataset_details, ai_details, row.text, row.event)[1], axis=1)
#         #else:
#         #    df_dataset[ai_details['id']] = df_dataset.apply(lambda row: get_label(dataset_details, ai_details, row['text'])[1])
# #

# %%
df_dataset.to_csv(export_location, index_label=False)
